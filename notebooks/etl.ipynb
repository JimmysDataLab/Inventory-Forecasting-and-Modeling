# %%
import sys
import os
sys.path.append(os.path.join(os.getenv("ROOT_DIR"),"etl"))
sys.path

#from etl.download import _download_csv_data
from utils import _schema,_names
from etl import _etl

# for name in _names:
#     status = _etl("csv","parquet",name)
#     print(name,status)
