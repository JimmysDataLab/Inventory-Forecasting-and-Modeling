# %%
import os
from dotenv import load_dotenv
load_dotenv()

import sys
sys.path.append(os.path.join(os.getenv("ROOT_DIR"),"etl"))

from utils import _names
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("spark://localhost:7077").getOrCreate()
path = os.path.join(os.getenv("DATA_DIR"),"parquet")

# %%
train = spark.read.parquet(os.path.join(path_full,"train"))

# %%
train.show()
# Out:
# +-------+----------+---------+--------------------+--------+-----------+
# |     id|      date|store_nbr|              family|   sales|onpromotion|
# +-------+----------+---------+--------------------+--------+-----------+
# |2733056|2017-03-18|       43|      PREPARED FOODS|  58.004|          0|
# |2733057|2017-03-18|       43|             PRODUCE| 1295.68|          8|
# |2733058|2017-03-18|       43|SCHOOL AND OFFICE...|     0.0|          0|
# |2733059|2017-03-18|       43|             SEAFOOD|     0.0|          0|
# |2733060|2017-03-18|       44|          AUTOMOTIVE|    30.0|          0|
# |2733061|2017-03-18|       44|           BABY CARE|     0.0|          0|
# |2733062|2017-03-18|       44|              BEAUTY|    15.0|          0|
# |2733063|2017-03-18|       44|           BEVERAGES| 16510.0|         35|
# |2733064|2017-03-18|       44|               BOOKS|     2.0|          0|
# |2733065|2017-03-18|       44|        BREAD/BAKERY|2384.839|          7|
# ...
